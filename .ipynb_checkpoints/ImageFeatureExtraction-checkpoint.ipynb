# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# %matplotlib inline

# %%
#!pip install opencv-python

# %%
imagePath = 'images/dog.jpg'

image = cv2.imread(imagePath)

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# (667, 500, 3)

# %%
image
# Out:
# array([[[ 80, 118, 120],
#         [ 77, 115, 117],
#         [ 73, 111, 113],
#         ...,
#         [ 24,  30,  41],
#         [ 28,  34,  45],
#         [ 30,  36,  47]],
#
#        [[ 81, 119, 121],
#         [ 78, 116, 118],
#         [ 74, 112, 114],
#         ...,
#         [ 24,  33,  43],
#         [ 27,  33,  44],
#         [ 26,  35,  45]],
#
#        [[ 81, 119, 123],
#         [ 78, 116, 120],
#         [ 75, 113, 117],
#         ...,
#         [ 25,  35,  45],
#         [ 25,  34,  44],
#         [ 23,  33,  43]],
#
#        ...,
#
#        [[ 96, 169, 167],
#         [ 97, 170, 168],
#         [ 97, 173, 169],
#         ...,
#         [ 44, 120, 108],
#         [ 54, 130, 118],
#         [ 52, 128, 116]],
#
#        [[ 96, 169, 167],
#         [ 97, 170, 168],
#         [ 97, 173, 169],
#         ...,
#         [ 44, 120, 108],
#         [ 54, 130, 118],
#         [ 52, 128, 116]],
#
#        [[ 96, 169, 167],
#         [ 97, 170, 168],
#         [ 97, 173, 169],
#         ...,
#         [ 44, 120, 108],
#         [ 54, 130, 118],
#         [ 52, 128, 116]]], dtype=uint8)

# %%
image[0][0]
# Out:
# array([ 80, 118, 120], dtype=uint8)

# %%
size=(32,32)
resized_image_feature_vector = cv2.resize(image, size)

# %%
plt.imshow(resized_image_feature_vector)

# %%
resized_image_feature_vector.shape
# Out:
# (32, 32, 3)

# %%
resized_image_feature_vector
# Out:
# array([[[ 67, 113, 120],
#         [ 63, 107, 106],
#         [ 74, 150, 159],
#         ...,
#         [ 58, 134, 130],
#         [ 43, 104, 104],
#         [ 34,  47,  55]],
#
#        [[ 54, 103,  87],
#         [ 48, 157, 165],
#         [ 69, 114, 113],
#         ...,
#         [ 46, 113,  97],
#         [ 38, 111,  93],
#         [ 38, 131, 124]],
#
#        [[ 48, 136, 145],
#         [ 45, 120, 121],
#         [ 57, 135, 142],
#         ...,
#         [  8,  62,  57],
#         [ 13,  38,  34],
#         [ 42, 105, 105]],
#
#        ...,
#
#        [[ 35, 122, 105],
#         [ 79, 142, 147],
#         [ 91, 147, 148],
#         ...,
#         [ 84, 169, 161],
#         [ 58, 131, 125],
#         [ 86, 152, 147]],
#
#        [[ 78, 141, 133],
#         [ 65, 131, 127],
#         [ 54, 129, 121],
#         ...,
#         [ 79, 150, 143],
#         [ 86, 147, 140],
#         [ 58, 132, 124]],
#
#        [[ 87, 161, 155],
#         [ 64, 128, 122],
#         [ 69, 145, 132],
#         ...,
#         [ 69, 154, 142],
#         [ 61, 140, 127],
#         [ 82, 144, 135]]], dtype=uint8)

# %%
resized_flattened_image_feature_vector = resized_image_feature_vector.flatten()

# %%
resized_flattened_image_feature_vector
# Out:
# array([ 67, 113, 120, ...,  82, 144, 135], dtype=uint8)

# %%
len(resized_flattened_image_feature_vector)
# Out:
# 3072

# %%
image_grayscale = cv2.imread(imagePath, cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(image_grayscale)

# %%
image_grayscale.shape
# Out:
# (667, 500)

# %%
expanded_image_grayscale = np.expand_dims(image_grayscale, axis=2)
expanded_image_grayscale.shape
# Out:
# (667, 500, 1)
